# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime 
import numpy as np

df = pd.read_csv("battery_data_1.csv") #flight data 1
# df = pd.read_csv("battery_data_2.csv") #flight data 2
        
voltage = df["volt"].values # as numpy array
current = list(df["curr"].values) # as python array

# %%
plt.plot(voltage)

# %%
plt.plot(current)

# %%
times = df["timeus"].values
# Out:
# array([1.33989580e+09, 1.33999605e+09, 1.34009665e+09, ...,
#        1.78592205e+09, 1.78602240e+09, 1.78612330e+09])

# %%
np.savetxt('Flight_1_current', current)

# %%
time = times - times[0]

# %%
times
# Out:
# array([1.33989580e+09, 1.33999605e+09, 1.34009665e+09, ...,
#        1.78592205e+09, 1.78602240e+09, 1.78612330e+09])
